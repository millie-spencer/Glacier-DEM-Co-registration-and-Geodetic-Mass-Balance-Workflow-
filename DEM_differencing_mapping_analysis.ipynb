# %% [markdown]
# # Glacier DEM Analysis Workflow
# This notebook replaces an ArcPy workflow with fully open-source Python tools to:
# - Clip DEMs to glacier polygons
# - Compute elevation change (difference) rasters
# - Perform zonal statistics
# - Calculate glacier mass balance
# - Visualize difference rasters
#
# 👉 Run each cell section-by-section and customize paths to your local data.

# %%
import os
import numpy as np
import geopandas as gpd
import rasterio
import rioxarray as rxr
import matplotlib.pyplot as plt
from rasterstats import zonal_stats
print("Modules imported")
# Out:
# Modules imported

# %%
# SET YOUR OWN PATHS BELOW
raster_folder = "/Users/milliespencer/Desktop/70_Years_MB Nevados/v1_coregistered_dems" #here's where you store your DEMs
polygon_clips = "example_data_Nevados/Nevados_glacier_shapefiles/Nevados_shapefile_DGA2019/Nevados_polygons_DGA2019.shp" #here's where you store your glacier polygons
stats_field = "COD_GLA" # specify which attribute to reference during the analysis, typically either glacier ID (COD_GLA) or area (AREA_KM2)
snap_raster_path = os.path.join(raster_folder, "CerroBlanco_projected_raster_SRTM_projected_raster_nuth_x+9.32_y+8.27_z+6.54_align.tif") # pick which DEM will be your snap raster (to which your other DEMs will be aligned)
baseline_raster = snap_raster_path
output_folder = "/Users/milliespencer/Desktop/70_Years_MB Nevados/python_workflow_outputs"

# %%
raster_path = "/Users/milliespencer/Desktop/70_Years_MB Nevados/v1_coregistered_dems/CerroBlanco_projected_raster_SRTM_projected_raster_nuth_x+9.32_y+8.27_z+6.54_align.tif"
with rasterio.open(raster_path) as src:
    data = src.read(1)  # Read the first band as a NumPy array

# %% [markdown]
# ## 1. Clip Rasters to Glacier Polygons

# %%
# Load the glacier polygons
glacier_polygons = gpd.read_file(polygon_clips)

# Loop over all rasters in the folder
for filename in os.listdir(raster_folder):
    if filename.endswith('.tif') and not filename.endswith('clp.tif'):
        full_path = os.path.join(raster_folder, filename)
        print(f"Clipping: {filename}")
        
        # Open the raster and get its CRS
        raster = rxr.open_rasterio(full_path, masked=True).squeeze()
        raster_crs = raster.rio.crs
        
        # Reproject glacier polygons to the raster's CRS
        glacier_polygons_reprojected = glacier_polygons.to_crs(raster_crs)

        # Clip the raster
        clipped = raster.rio.clip(glacier_polygons_reprojected.geometry, glacier_polygons_reprojected.crs, drop=True)

        # Save the clipped raster
        output_name = os.path.join(output_folder, f"{filename[:20]}_clp.tif")
        clipped.rio.to_raster(output_name)
        print(f"Saved clipped raster: {output_name}")
# Out:
# Clipping: IGM_projected_raster_SRTM_projected_raster_nuth_x-35.24_y-7.77_z-10.15_align.tif
# Saved clipped raster: /Users/milliespencer/Desktop/70_Years_MB Nevados/python_workflow_outputs/IGM_projected_raster_clp.tif
# Clipping: s37_w072_1arc_v3.tif
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 28 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 29 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 30 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 31 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 32 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 33 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 34 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 35 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 36 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 37 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 38 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 39 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 40 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 41 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 42 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 43 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 44 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 45 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 46 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 47 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 48 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 49 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 50 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 51 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 52 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 53 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 54 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 55 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 56 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 57 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 58 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 59 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 60 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 61 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 62 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 63 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 64 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 65 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 66 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 67 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 68 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 69 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 70 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 71 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 72 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 73 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 74 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 75 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 76 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 77 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 78 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 79 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 80 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 81 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 82 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 83 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 84 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 85 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 86 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 87 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 88 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 89 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 90 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 91 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 92 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 93 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 94 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 95 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 96 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 97 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 98 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 99 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 100 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 101 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 102 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 103 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 104 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 105 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 106 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 107 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 108 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 109 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 110 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 111 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 112 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 113 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 114 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 115 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 116 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 117 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 118 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 119 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 120 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 121 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 122 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 123 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 124 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 125 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 126 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 127 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 128 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 129 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 130 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 131 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 132 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 133 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 134 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 135 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 136 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 137 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 138 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 139 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 140 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 141 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 142 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 143 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 144 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 145 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 146 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 147 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 148 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 149 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 150 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 151 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 152 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 153 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 154 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 155 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 156 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 157 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 158 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 159 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 160 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 161 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 162 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 163 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 164 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 165 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 166 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 167 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 168 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 169 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 170 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 171 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 172 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 173 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 174 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 175 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 176 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 177 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 178 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 179 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 180 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 181 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 182 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 183 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 184 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 185 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 186 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 187 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 188 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 189 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 190 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 191 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 192 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 193 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 194 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 195 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 196 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 197 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 198 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 199 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 200 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 201 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 202 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 203 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 204 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 205 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 206 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 207 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 208 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 209 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 210 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 211 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 212 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 213 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 214 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 215 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 216 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 217 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 218 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 219 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 220 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 221 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 222 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 223 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 224 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 225 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 226 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 227 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 228 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 229 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 230 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 231 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 232 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 233 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 234 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 235 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 236 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 237 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 238 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 239 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 240 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 241 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 242 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 243 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 244 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 245 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 246 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 247 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 248 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 249 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 250 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 251 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 252 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 253 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 254 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 255 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 256 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 257 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 258 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 259 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 260 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 261 will not be rasterized.
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 915 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 916 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 917 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 918 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 919 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 920 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 921 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 922 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 923 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 924 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 925 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 926 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 927 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 928 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 929 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 930 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 931 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 932 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 933 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 934 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 935 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 936 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 937 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 938 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 939 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 940 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 941 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 942 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 943 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 944 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 945 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 946 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 947 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 948 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 949 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 950 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 951 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 952 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 953 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 954 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 955 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 956 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 957 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 958 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 959 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 960 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 961 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 962 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 963 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 964 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 965 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 966 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 967 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 968 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 969 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 970 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 971 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 972 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 973 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 974 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 975 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 976 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 977 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 978 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 979 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 980 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 981 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 982 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 983 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 984 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 985 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 986 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 987 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 988 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 989 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 990 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 991 will not be rasterized.
#   warnings.warn(
# /Users/milliespencer/miniconda3/envs/glacier-env/lib/python3.10/site-packages/rasterio/features.py:336: ShapeSkipWarning: Invalid or empty shape None at index 992 will not be rasterized.
#   warnings.warn(

# %% [markdown]
# ## 2. Compute Raster Differences vs. Baseline

# %%
baseline = rxr.open_rasterio(baseline_raster, masked=True).squeeze()

for filename in os.listdir(output_folder):
    if filename.endswith('clp.tif'):
        full_path = os.path.join(output_folder, filename)

        if os.path.basename(baseline_raster)[:20] in filename:
            continue

        try:
            raster = rxr.open_rasterio(full_path, masked=True).squeeze()
            difference = raster - baseline

            diff_path = os.path.join(output_folder, filename.replace('_clp.tif', '_diff.tif'))
            difference.rio.to_raster(diff_path)
            print(f"Saved difference raster: {diff_path}")

        except Exception as e:
            print(f"Error processing {filename}: {e}")

# %% [markdown]
# ## 3. Zonal Statistics and Mass Balance

# %%
for filename in os.listdir(output_folder):
    if filename.endswith('diff.tif'):
        raster_path = os.path.join(output_folder, filename)

        stats = zonal_stats(
            polygon_clips,
            raster_path,
            stats=["mean", "std", "min", "max", "count", "sum"],
            geojson_out=True,
            nodata=None
        )

        stats_gdf = gpd.GeoDataFrame.from_features(stats)
        stats_gdf['area_m2'] = stats_gdf['geometry'].area * 1e6
        stats_gdf['mass_balance_mwe'] = (858 * stats_gdf['mean']) / (1000 * stats_gdf['area_m2'])

        output_csv = os.path.join(output_folder, filename.replace('.tif', '_zonalStats.csv'))
        stats_gdf[[stats_field, 'mean', 'std', 'min', 'max', 'count', 'sum', 'area_m2', 'mass_balance_mwe']].to_csv(output_csv, index=False)
        print(f"Saved zonal stats: {output_csv}")

# %% [markdown]
# ## 4. Visualize Difference Rasters

# %%
for filename in os.listdir(output_folder):
    if filename.endswith('diff.tif'):
        map_path = os.path.join(output_folder, filename)
        with rasterio.open(map_path) as src:
            raster_data = src.read(1)
            extent = [src.bounds.left, src.bounds.right, src.bounds.bottom, src.bounds.top]

        plt.figure(figsize=(8, 6))
        plt.imshow(raster_data, cmap='viridis', extent=extent)
        plt.colorbar(label='Elevation Change (m)')
        plt.title(f"Raster Difference: {filename}")
        plt.xlabel("Longitude")
        plt.ylabel("Latitude")
        plt.show()
